# %%
OR src_nameofmedication LIKE '%Clinical domain review (diabetes YOC)%'
OR src_nameofmedication LIKE '%Diabetic monitoring - injection site not checked%'
OR src_nameofmedication LIKE '%Diabetes monitoring admin.%'
OR src_nameofmedication LIKE '%Seen in diabetic clinic%'
OR src_nameofmedication LIKE '%Diabetes care plan agreed%'
OR src_nameofmedication LIKE '%O/E - Left diabetic foot at low risk%'
OR src_nameofmedication LIKE '%O/E - Right diabetic foot at low risk%'
OR src_nameofmedication LIKE '%H/O: diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabetic retinopathy screening%'
OR src_nameofmedication LIKE '%Seen in diabetic foot clinic%'
OR src_nameofmedication LIKE '%Annual review of diabetic foot assessment%'
OR src_nameofmedication LIKE '%Under care of diabetic foot screener%'
OR src_nameofmedication LIKE '%Pre-diabetes%'
OR src_nameofmedication LIKE '%Education : Diabetes monitoring technique%'
OR src_nameofmedication LIKE '%Diabetic dietary review%'
OR src_nameofmedication LIKE '%O/E - Right diabetic foot at moderate risk%'
OR src_nameofmedication LIKE '%Diabetic foot examination%'
OR src_nameofmedication LIKE '%O/E - Left diabetic foot at moderate risk%'
OR src_nameofmedication LIKE '%Diabetic retinopathy screening refused%'
OR src_nameofmedication LIKE '%At risk of diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabetes monitoring invitation%'
OR src_nameofmedication LIKE '%Referral to XPERT diabetes structured education programme%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus%'
OR src_nameofmedication LIKE '%O/E - no left diabetic retinopathy%'
OR src_nameofmedication LIKE '%O/E - no right diabetic retinopathy%'
OR src_nameofmedication LIKE '%O/E - Left diabetic foot at high risk%'
OR src_nameofmedication LIKE '%O/E - Right diabetic foot at high risk%'
OR src_nameofmedication LIKE '%Diabetic peripheral neuropathy screening%'
OR src_nameofmedication LIKE '%Cong heart fail, hypertens, age, diab, stroke 2 risk score%'
OR src_nameofmedication LIKE '%Diabetic leaflet given%'
OR src_nameofmedication LIKE '%Diabetes monitoring first letter%'
OR src_nameofmedication LIKE '%Patient offered diabetes structured education programme%'
OR src_nameofmedication LIKE '%Diabetic foot risk assessment%'
OR src_nameofmedication LIKE '%Diabetes structured education programme declined%'
OR src_nameofmedication LIKE '%Diabetic foot examination declined%'
OR src_nameofmedication LIKE '%Emotional domain review (diabetes YOC)%'
OR src_nameofmedication LIKE '%Non proliferative diabetic retinopathy%'
OR src_nameofmedication LIKE '%Health education - diabetes%'
OR src_nameofmedication LIKE '%FH: Diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabetes UK diabetes risk score%'
OR src_nameofmedication LIKE '%Diabetic assessment of erectile dysfunction%'
OR src_nameofmedication LIKE '%Diabetic on oral treatment%'
OR src_nameofmedication LIKE '%Diabetes: practice programme%'
OR src_nameofmedication LIKE '%Diabetic 6 month review%'
OR src_nameofmedication LIKE '%O/E - right eye background diabetic retinopathy%'
OR src_nameofmedication LIKE '%[V]Family history of diabetes mellitus%'
OR src_nameofmedication LIKE '%Patient advised about diabetic diet%'
OR src_nameofmedication LIKE '%Diabetic diet%'
OR src_nameofmedication LIKE '%Diabetic neuropathy%'
OR src_nameofmedication LIKE '%Diabetes type II review%'
OR src_nameofmedication LIKE '%Type II diabetic dietary review%'
OR src_nameofmedication LIKE '%Patient diabetes education review%'
OR src_nameofmedication LIKE '%Excepted from diabetes qual indicators: Patient unsuitable%'
OR src_nameofmedication LIKE '%Patient on maximal tolerated therapy for diabetes%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus%'
OR src_nameofmedication LIKE '%Seen in diabetic nurse consultant clinic%'
OR src_nameofmedication LIKE '%Under care of diabetes specialist nurse%'
OR src_nameofmedication LIKE '%Behavioural domain review (diabetes YOC)%'
OR src_nameofmedication LIKE '%O/E - left eye background diabetic retinopathy%'
OR src_nameofmedication LIKE '%Attending Diabetes satellite clinic%'
OR src_nameofmedication LIKE '%Referral for diabetic retinopathy screening%'
OR src_nameofmedication LIKE '%Education : Rationale of treatment and use of tablets/insulin (diabetes)%'
OR src_nameofmedication LIKE '%No diabetic retinopathy%'
OR src_nameofmedication LIKE '%Refer to diabetic foot screener%'
OR src_nameofmedication LIKE '%Diabetes clinical management plan%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Footcare%'
OR src_nameofmedication LIKE '%Referral to diabetes structured education programme%'
OR src_nameofmedication LIKE '%Diabetic monitoring%'
OR src_nameofmedication LIKE '%Diabetic retinopathy 12 month review%'
OR src_nameofmedication LIKE '%O/E - right eye preproliferative diabetic retinopathy%'
OR src_nameofmedication LIKE '%Diabetic on insulin%'
OR src_nameofmedication LIKE '%NHS Diabetes Prevention Programme%'
OR src_nameofmedication LIKE '%Diabetic monitoring - injection sites%'
OR src_nameofmedication LIKE '%Follow-up diabetic assessment%'
OR src_nameofmedication LIKE '%Referral to diabetes nurse%'
OR src_nameofmedication LIKE '%FH: Diabetes mellitus in first degree relative%'
OR src_nameofmedication LIKE '%Diabetic review%'
OR src_nameofmedication LIKE '%Family history of diabetes mellitus type II%'
OR src_nameofmedication LIKE '%Excepted from diabetes quality indicators: Informed dissent%'
OR src_nameofmedication LIKE '%Diabetes monitoring second letter%'
OR src_nameofmedication LIKE '%Diabetes medication review%'
OR src_nameofmedication LIKE '%Diabetes Education Compl. : Monitoring of Diabetes%'
OR src_nameofmedication LIKE '%Diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabetic Clinic%'
OR src_nameofmedication LIKE '%Diabetic medicine%'
OR src_nameofmedication LIKE '%Education about lifestyle for risk of diabetes%'
OR src_nameofmedication LIKE '%Declined diabetic retinopathy screening%'
OR src_nameofmedication LIKE '%Moderate non proliferative diabetic retinopathy%'
OR src_nameofmedication LIKE '%Diabetic ketoacidosis%'
OR src_nameofmedication LIKE '%Diabetic annual review%'
OR src_nameofmedication LIKE '%H/O: diabetes mellitus type 1%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : What is Diabetes?%'
OR src_nameofmedication LIKE '%Diabetic dietary review declined%'
OR src_nameofmedication LIKE '%Diabetes mellitus screening%'
OR src_nameofmedication LIKE '%Diabetic macular oedema%'
OR src_nameofmedication LIKE '%H/O: diabetes mellitus type 2%'
OR src_nameofmedication LIKE '%Seen in community diabetes specialist clinic%'
OR src_nameofmedication LIKE '%Family history of diabetes mellitus type 1%'
OR src_nameofmedication LIKE '%No significant family history of diabetes%'
OR src_nameofmedication LIKE '%Diabetes monitoring verbal invite%'
OR src_nameofmedication LIKE '%Knowledge / health beliefs domain review (diabetes YOC)%'
OR src_nameofmedication LIKE '%Non-diabetic hyperglycaemia%'
OR src_nameofmedication LIKE '%Referral to DAFNE diabetes structured educn prog declined%'
OR src_nameofmedication LIKE '%QDiabetes risk calculator%'
OR src_nameofmedication LIKE '%No family history diabetes%'
OR src_nameofmedication LIKE '%Diabetic antenatal clinic%'
OR src_nameofmedication LIKE '%Gestational diabetes mellitus%'
OR src_nameofmedication LIKE '%Background diabetic retinopathy%'
OR src_nameofmedication LIKE '%Diabetic on diet only%'
OR src_nameofmedication LIKE '%Diabetes screening invitation%'
OR src_nameofmedication LIKE '%Type 1 diabetes mellitus with ketoacidosis%'
OR src_nameofmedication LIKE '%Referral to community diabetes service%'
OR src_nameofmedication LIKE '%Education about diabetes and driving%'
OR src_nameofmedication LIKE '%Education : Explaination of the diabetic condition%'
OR src_nameofmedication LIKE '%Has seen dietitian - diabetes%'
OR src_nameofmedication LIKE '%Diabetic monitoring NOS%'
OR src_nameofmedication LIKE '%O/E - Right diabetic foot - ulcerated%'
OR src_nameofmedication LIKE '%Referral to diabetologist%'
OR src_nameofmedication LIKE '%Did not attend diabetic clinic%'
OR src_nameofmedication LIKE '%O/E - Left diabetic foot - ulcerated%'
OR src_nameofmedication LIKE '%Seen in community diabetic specialist nurse clinic%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Illness Management%'
OR src_nameofmedication LIKE '%O/E - diabetic maculopathy absent both eyes%'
OR src_nameofmedication LIKE '%Exception reporting: diabetes quality indicators%'
OR src_nameofmedication LIKE '%Education : Why and when to test (Diabetes)%'
OR src_nameofmedication LIKE '%Education : Diabetic record keeping%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Hypoglycaemia%'
OR src_nameofmedication LIKE '%Renal diabetes%'
OR src_nameofmedication LIKE '%Diabetic nurse%'
OR src_nameofmedication LIKE '%Annual diabetic blood test%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Driving & Diabetes%'
OR src_nameofmedication LIKE '%Diabetic - follow-up default%'
OR src_nameofmedication LIKE '%Referral to diabetes special interest general practitioner%'
OR src_nameofmedication LIKE '%Referral to community diabetes clinic%'
OR src_nameofmedication LIKE '%O/E - right eye diabetic maculopathy%'
OR src_nameofmedication LIKE '%Neuropathic diabetic ulcer - foot%'
OR src_nameofmedication LIKE '%Diabetic foot screen%'
OR src_nameofmedication LIKE '%Diabetic diet - good compliance%'
OR src_nameofmedication LIKE '%Mild non proliferative diabetic retinopathy%'
OR src_nameofmedication LIKE '%Patient consented to shared diabetic computer record%'
OR src_nameofmedication LIKE '%Diabetes: shared care programme%'
OR src_nameofmedication LIKE '%Seen in diabetic eye clinic%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Hyperglycaemia%'
OR src_nameofmedication LIKE '%Diabetic monitoring - injection site check declined%'
OR src_nameofmedication LIKE '%Diabetes structured education programme not available%'
OR src_nameofmedication LIKE '%Diabetic foot screening invitation first letter%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus without complication%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Any Other Problems%'
OR src_nameofmedication LIKE '%Education : Diabetic Symptoms%'
OR src_nameofmedication LIKE '%Diabetic pre-pregnancy counselling%'
OR src_nameofmedication LIKE '%Referral to diabetic clinic%'
OR src_nameofmedication LIKE '%Did not complet XPERT diabetes structured education programm%'
OR src_nameofmedication LIKE '%Referral to NHS Diabetes Prevention Programme%'
OR src_nameofmedication LIKE '%Did not attend diabetes structured education programme%'
OR src_nameofmedication LIKE '%Provision of written information about diabetes and driving%'
OR src_nameofmedication LIKE '%Fundoscopy - diabetic check%'
OR src_nameofmedication LIKE '%Suspected diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabetes monitoring third letter%'
OR src_nameofmedication LIKE '%Diabetic digital retinopathy screening offered%'
OR src_nameofmedication LIKE '%Did not attend diabetic retinopathy clinic%'
OR src_nameofmedication LIKE '%High risk of diabetes mellitus%'
OR src_nameofmedication LIKE '%Referral to NHS Diabetes Prevention Programme declined%'
OR src_nameofmedication LIKE '%Discharged from care of diabetes specialist nurse%'
OR src_nameofmedication LIKE '%Diabetic foot screening invitation%'
OR src_nameofmedication LIKE '%Diabetic foot screening invitation second letter%'
OR src_nameofmedication LIKE '%Chronic painful diabetic neuropathy%'
OR src_nameofmedication LIKE '%Diabetes care by hospital only%'
OR src_nameofmedication LIKE '%Diabetes monitoring short msg service text msg 3rd invitaton%'
OR src_nameofmedication LIKE '%Diabetic - poor control%'
OR src_nameofmedication LIKE '%Seen by general practitioner special interest in diabetes%'
OR src_nameofmedication LIKE '%Type I diabetic dietary review%'
OR src_nameofmedication LIKE '%Diabetic erectile dysfunction review%'
OR src_nameofmedication LIKE '%Diabetes structured education programme completed%'
OR src_nameofmedication LIKE '%Diabetes monitoring telephone invite%'
OR src_nameofmedication LIKE '%XPERT diabetes structured education programme completed%'
OR src_nameofmedication LIKE '%O/E - right eye proliferative diabetic retinopathy%'
OR src_nameofmedication LIKE '%Dietary advice for type II diabetes%'
OR src_nameofmedication LIKE '%Initial diabetic assessment%'
OR src_nameofmedication LIKE '%Did not complete diabetes structured education programme%'
OR src_nameofmedication LIKE '%Diabetes monitoring short msg service text msg 1st invitaton%'
OR src_nameofmedication LIKE '%Mother has Diabetes%'
OR src_nameofmedication LIKE '%Diabetic injection administration education%'
OR src_nameofmedication LIKE '%Diabetes dietitian%'
OR src_nameofmedication LIKE '%Diabetes Edu Compl. : Urine Ketone Test (Type I)%'
OR src_nameofmedication LIKE '%Education : General effects of illness and diabetes%'
OR src_nameofmedication LIKE '%Diabetes Year of Care annual review%'
OR src_nameofmedication LIKE '%Diabetes monitor invitation by SMS (short message service)%'
OR src_nameofmedication LIKE '%H/O: gestational diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabetic retinopathy screening offered%'
OR src_nameofmedication LIKE '%Diabetes monitoring check done%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Identification%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Insulins%'
OR src_nameofmedication LIKE '%Housebound diabetes care%'
OR src_nameofmedication LIKE '%Attended diabetes structured education programme%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Eye Care%'
OR src_nameofmedication LIKE '%Insulin treated Type 2 diabetes mellitus%'
OR src_nameofmedication LIKE '%Family/carer referral to diabetes structured education prog%'
OR src_nameofmedication LIKE '%Education : Diabetic backup literature%'
OR src_nameofmedication LIKE '%Discharged from diabetes shared care programme%'
OR src_nameofmedication LIKE '%Referral to DAFNE diabetes structured education programme%'
OR src_nameofmedication LIKE '%Diabetes mellitus, adult onset, no mention of complication%'
OR src_nameofmedication LIKE '%QDiabetes 10 year diabetes risk%'
OR src_nameofmedication LIKE '%Under care of hospital-based diabetes specialist nurse%'
OR src_nameofmedication LIKE '%Seen by diabetes specialist nurse%'
OR src_nameofmedication LIKE '%O/E - left eye preproliferative diabetic retinopathy%'
OR src_nameofmedication LIKE '%Attended DAFNE diabetes structured education programme%'
OR src_nameofmedication LIKE '%DAFNE diabetes structured education programme completed%'
OR src_nameofmedication LIKE '%Age, BP, clinical feat, duration, diabetes 2 stroke rsk scre%'
OR src_nameofmedication LIKE '%In-house diabetic foot screening follow-up appointment%'
OR src_nameofmedication LIKE '%Referral to DESMOND diabetes structured programme%'
OR src_nameofmedication LIKE '%Referral to type I diabetes structured education programme%'
OR src_nameofmedication LIKE '%Diabetic relative%'
OR src_nameofmedication LIKE '%O/E - left eye diabetic maculopathy%'
OR src_nameofmedication LIKE '%Diabetic retinopathy screening administrative status%'
OR src_nameofmedication LIKE '%Social domain review (diabetes YOC)%'
OR src_nameofmedication LIKE '%Diabetic retinopathy screening not indicated%'
OR src_nameofmedication LIKE '%Diabetic monitoring - injection sites normal%'
OR src_nameofmedication LIKE '%Diabetes Education Compl. : Looking After Yourself%'
OR src_nameofmedication LIKE '%Diabetic retinopathy%'
OR src_nameofmedication LIKE '%Provsn written information about diabetes & high cholesterol%'
OR src_nameofmedication LIKE '%Dietary advice for diabetes mellitus%'
OR src_nameofmedication LIKE '%Eligibility temporarily inactive for diabetic retinop screen%'
OR src_nameofmedication LIKE '%Diabetic retinopathy 6 month review%'
OR src_nameofmedication LIKE '%Diabetes mellitus with persistent proteinuria%'
OR src_nameofmedication LIKE '%Diabetic foot examination not indicated%'
OR src_nameofmedication LIKE '%Diabetic Control Clinic%'
OR src_nameofmedication LIKE '%Did not attend diabetes foot screening%'
OR src_nameofmedication LIKE '%Diabetic weight reducing diet%'
OR src_nameofmedication LIKE '%Diabetic - good control%'
OR src_nameofmedication LIKE '%Diabetes self-management plan agreed%'
OR src_nameofmedication LIKE '%Diabetic care%'
OR src_nameofmedication LIKE '%Diabetic on insulin and oral treatment%'
OR src_nameofmedication LIKE '%Attended XPERT diabetes structured education programme%'
OR src_nameofmedication LIKE '%Referral to community diabetes specialist nurse%'
OR src_nameofmedication LIKE '%Seen by diabetic liaison nurse%'
OR src_nameofmedication LIKE '%Attends diabetes monitoring%'
OR src_nameofmedication LIKE '%Diabetic peripheral neuropathic pain%'
OR src_nameofmedication LIKE '%Diabetes care plan declined%'
OR src_nameofmedication LIKE '%High risk of diabetes mellitus annual review%'
OR src_nameofmedication LIKE '%Diabetes treatment satisfaction questionnaire%'
OR src_nameofmedication LIKE '%Erectile dysfunction due to diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabetes resolved%'
OR src_nameofmedication LIKE '%O/E - left eye stable treated prolif diabetic retinopathy%'
OR src_nameofmedication LIKE '%O/E - right eye stable treated prolif diabetic retinopathy%'
OR src_nameofmedication LIKE '%O/E - left eye proliferative diabetic retinopathy%'
OR src_nameofmedication LIKE '%Pre-conception advice for diabetes mellitus%'
OR src_nameofmedication LIKE '%Advised ([?AND/OR advice ?AND/OR eductn]) diabetes driving%'
OR src_nameofmedication LIKE '%Diabetic - adequate control%'
OR src_nameofmedication LIKE '%NHS diabetes prevention programme invitation first letter%'
OR src_nameofmedication LIKE '%Pan retinal photocoagulation for diabetes%'
OR src_nameofmedication LIKE '%NHS Diabetes Prevention Programme invitation%'
OR src_nameofmedication LIKE '%Diabetes management plan given%'
OR src_nameofmedication LIKE '%Diabetic foot%'
OR src_nameofmedication LIKE '%Declined referral to National Health Service diabetes programme - digital intervention%'
OR src_nameofmedication LIKE '%Diabetic ulcer%'
OR src_nameofmedication LIKE '%Infant of mother with gestational diabetes%'
OR src_nameofmedication LIKE '%Refuses diabetes monitoring%'
OR src_nameofmedication LIKE '%Mixed diabetic ulcer - foot%'
OR src_nameofmedication LIKE '%Excepted from diabetes qual indicators: service unavailable%'
OR src_nameofmedication LIKE '%Diabetic foot care education%'
OR src_nameofmedication LIKE '%Diabetic Impotence%'
OR src_nameofmedication LIKE '%Severe non proliferative diabetic retinopathy%'
OR src_nameofmedication LIKE '%Education in self management of diabetes%'
OR src_nameofmedication LIKE '%O/E - diabetic maculopathy present both eyes%'
OR src_nameofmedication LIKE '%Diabetic hand syndrome%'
OR src_nameofmedication LIKE '%Proliferative diabetic retinopathy%'
OR src_nameofmedication LIKE '%Diabetic nephropathy%'
OR src_nameofmedication LIKE '%Steroid-induced diabetes%'
OR src_nameofmedication LIKE '%O/E - Right diabetic foot at increased risk%'
OR src_nameofmedication LIKE '%Referral to multidisciplinary diabetic clinic%'
OR src_nameofmedication LIKE '%Referral to diabetic liaison nurse%'
OR src_nameofmedication LIKE '%Proteinuric diabetic nephropathy%'
OR src_nameofmedication LIKE '%Cellulitis in diabetic foot%'
OR src_nameofmedication LIKE '%Education : Role of Diabetes UK%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus - poor control%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with persistent microalbuminuria%'
OR src_nameofmedication LIKE '%Diabetic patient unsuitable for digital retinal photography%'
OR src_nameofmedication LIKE '%Referral to diabetes preconception counselling clinic%'
OR src_nameofmedication LIKE '%Seen in multidisciplinary diabetic clinic%'
OR src_nameofmedication LIKE '%Joint consultn pracse nurse & comm diabetes specialist nurse%'
OR src_nameofmedication LIKE '%Diabetic 4 month review in primary care%'
OR src_nameofmedication LIKE '%Diabetes Obesity Clinic%'
OR src_nameofmedication LIKE '%Diabetes monitoring call%'
OR src_nameofmedication LIKE '%Possible indicators: Arterial Disease: Diabetes%'
OR src_nameofmedication LIKE '%NHS Diabetes Prevention Programme not completed%'
OR src_nameofmedication LIKE '%Diabetic maculopathy%'
OR src_nameofmedication LIKE '%NHS Diabetes Prevention Programme completed%'
OR src_nameofmedication LIKE '%O/E - Left diabetic foot at increased risk%'
OR src_nameofmedication LIKE '%Preproliferative diabetic retinopathy%'
OR src_nameofmedication LIKE '%Education : Diabetes UK local groups%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Additional Support%'
OR src_nameofmedication LIKE '%Diabetic foot screening invitation third letter%'
OR src_nameofmedication LIKE '%Seen by diabetologist%'
OR src_nameofmedication LIKE '%Did not attend XPERT diabetes structured education programme%'
OR src_nameofmedication LIKE '%Specific advice for diabetics%'
OR src_nameofmedication LIKE '%Provision written information abt diabetes & high HbA1c levl%'
OR src_nameofmedication LIKE '%Type II diabetes on diet only%'
OR src_nameofmedication LIKE '%Diabetic diet - poor compliance%'
OR src_nameofmedication LIKE '%No family history of diabetes Mellitus%'
OR src_nameofmedication LIKE '%Symptomatic diabetic peripheral neuropathy%'
OR src_nameofmedication LIKE '%Provision of diabetes clinical summary%'
OR src_nameofmedication LIKE '%Diabetic Transition Clinic%'
OR src_nameofmedication LIKE '%Referred to National Health Service diabetes programme - digital intervention%'
OR src_nameofmedication LIKE '%Proliferative diabetic retinopathy - high risk%'
OR src_nameofmedication LIKE '%Diabetic foot examined right%'
OR src_nameofmedication LIKE '%Diabetes mellitus excluded%'
OR src_nameofmedication LIKE '%NHS Diabetes Prevention Programme started%'
OR src_nameofmedication LIKE '%Diabetic lipid lowering diet%'
OR src_nameofmedication LIKE '%Attending diabetes clinic%'
OR src_nameofmedication LIKE '%Finnish diabetes risk score%'
OR src_nameofmedication LIKE '%NHS diabetes prevention programme short message service invitation%'
OR src_nameofmedication LIKE '%Diabetic autonomic neuropathy%'
OR src_nameofmedication LIKE '%Diabetes mellitus: no%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with ophthalmic complications%'
OR src_nameofmedication LIKE '%NHS diabetes prevention programme telephone invitation%'
OR src_nameofmedication LIKE '%Diabetic monitoring status%'
OR src_nameofmedication LIKE '%Diabetic neuropathic arthropathy%'
OR src_nameofmedication LIKE '%Patient held diabetic record issued%'
OR src_nameofmedication LIKE '%Lifestyle education for diabetes%'
OR src_nameofmedication LIKE '%Hypoglycaemic event in diabetes%'
OR src_nameofmedication LIKE '%No FH: Diabetes%'
OR src_nameofmedication LIKE '%Referral to diabetic eye clinic%'
OR src_nameofmedication LIKE '%Diabetes mellitus in remission%'
OR src_nameofmedication LIKE '%Latent autoimmune diabetes mellitus in adult%'
OR src_nameofmedication LIKE '%Diabetes UK- Diabetes risk score%'
OR src_nameofmedication LIKE '%Discharge from secondary care diabetes service%'
OR src_nameofmedication LIKE '%Attend diabetes educ self manage ongo new diagn struct prog%'
OR src_nameofmedication LIKE '%Understands diet - diabetes%'
OR src_nameofmedication LIKE '%Diabetic dermopathy%'
OR src_nameofmedication LIKE '%Education about diabetic retinopathy%'
OR src_nameofmedication LIKE '%Diabetes type 1 review%'
OR src_nameofmedication LIKE '%Diabetes monitoring admin.NOS%'
OR src_nameofmedication LIKE '%Diabetic child%'
OR src_nameofmedication LIKE '%Next Appointment at Diabetes Unit%'
OR src_nameofmedication LIKE '%Joint consultation GP & community diabetes specialist nurse%'
OR src_nameofmedication LIKE '%Provision of written information about diabetes and high BP%'
OR src_nameofmedication LIKE '%Diabetic Foot Risk Status for Scored Assessment%'
OR src_nameofmedication LIKE '%Family/carer attended diabetes structured education prog%'
OR src_nameofmedication LIKE '%Diabetes and high HbA1c information prescription (Diabetes UK) issued%'
OR src_nameofmedication LIKE '%Declined consent for diabetes year of care programme%'
OR src_nameofmedication LIKE '%Education : What to do with diabetic results%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus in remission%'
OR src_nameofmedication LIKE '%Proliferative diabetic retinopathy - iris neovascularisation%'
OR src_nameofmedication LIKE '%Retinal abnormality - diabetes-related%'
OR src_nameofmedication LIKE '%Diabetic polyneuropathy%'
OR src_nameofmedication LIKE '%[V]Screening for diabetes mellitus%'
OR src_nameofmedication LIKE '%Patient reports Diabetes and other endocrine disorders%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus - poor control%'
OR src_nameofmedication LIKE '%Diabetes monitoring default%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with persistent proteinuria%'
OR src_nameofmedication LIKE '%Ischaemic diabetic maculopathy%'
OR src_nameofmedication LIKE '%Central diabetes insipidus%'
OR src_nameofmedication LIKE '%Skin ulcer associated with diabetes mellitus%'
OR src_nameofmedication LIKE '%Type 2 diabetes mellitus with ketoacidosis%'
OR src_nameofmedication LIKE '%Retinal abnormality - non-diabetes%'
OR src_nameofmedication LIKE '%Excluded from diabetic retinopathy screening%'
OR src_nameofmedication LIKE '%Dietary advice for type I diabetes%'
OR src_nameofmedication LIKE '%Diabetic treatment changed%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Pregnancy%'
OR src_nameofmedication LIKE '%Hyperosmolar non-ketotic state in type II diabetes mellitus%'
OR src_nameofmedication LIKE '%Secondary diabetes mellitus%'
OR src_nameofmedication LIKE '%Patient main issue today (diabetes YOC)%'
OR src_nameofmedication LIKE '%New patients annual diabetic foot assessment%'
OR src_nameofmedication LIKE '%Refer diabetic liaison nurse%'
OR src_nameofmedication LIKE '%O/E - Right diabetic foot at risk%'
OR src_nameofmedication LIKE '%O/E - Left diabetic foot at risk%'
OR src_nameofmedication LIKE '%Diabetes clinic administration%'
OR src_nameofmedication LIKE '%Excluded from diabetic retinopathy screen physical disorder%'
OR src_nameofmedication LIKE '%Excluded from diabetic retinopthy screen as learn disability%'
OR src_nameofmedication LIKE '%Diabetes monitoring status%'
OR src_nameofmedication LIKE '%HbA1 - diabetic control%'
OR src_nameofmedication LIKE '%Type II diabetes on insulin%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with mononeuropathy%'
OR src_nameofmedication LIKE '%[EDTA] Diabetes Type II associated with renal failure%'
OR src_nameofmedication LIKE '%Microalbuminuric diabetic nephropathy%'
OR src_nameofmedication LIKE '%Diabetic monitoring - injection sites abnormal%'
OR src_nameofmedication LIKE '%Diabetic drug side effects%'
OR src_nameofmedication LIKE '%Referral to NHS diabetes prevention programme%'
OR src_nameofmedication LIKE '%Diabetic vitreous haemorrhage%'
OR src_nameofmedication LIKE '%[V]Personal history of gestational diabetes mellitus%'
OR src_nameofmedication LIKE '%Unstable diabetes%'
OR src_nameofmedication LIKE '%Diabetes mellitus with nephropathy NOS%'
OR src_nameofmedication LIKE '%Diabetes monitoring short msg service text msg 2nd invitaton%'
OR src_nameofmedication LIKE '%Diabetic necrobiosis lipoidica%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with neurological complications%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with neuropathic arthropathy%'
OR src_nameofmedication LIKE '%Diabetic hyperosmolar non-ketotic state%'
OR src_nameofmedication LIKE '%Diabetology D.V. done%'
OR src_nameofmedication LIKE '%Hb. A1C - diabetic control NOS%'
OR src_nameofmedication LIKE '%Diabetes self management plan%'
OR src_nameofmedication LIKE '%Asymptomatic diabetic neuropathy%'
OR src_nameofmedication LIKE '%Diabetes screening administration%'
OR src_nameofmedication LIKE '%Under care of community-based diabetes specialist nurse%'
OR src_nameofmedication LIKE '%Excluded diabetc retinop screen as under care ophthalmolgist%'
OR src_nameofmedication LIKE '%Diabetic retinopathy detected by national screening program%'
OR src_nameofmedication LIKE '%Diabetic Nephropathy (Not Proven by Biopsy)%'
OR src_nameofmedication LIKE '%Patient consent given for addition to diabetic register%'
OR src_nameofmedication LIKE '%Diabetic foot examined left%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus without complication%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with nephropathy%'
OR src_nameofmedication LIKE '%Diabetic department%'
OR src_nameofmedication LIKE '%Diabetes mellitus autosomal dominant%'
OR src_nameofmedication LIKE '%Ischaemic ulcer diabetic foot%'
OR src_nameofmedication LIKE '%Referral to diabetic register%'
OR src_nameofmedication LIKE '%Pregnancy and insulin-dependent diabetes mellitus%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with renal complications%'
OR src_nameofmedication LIKE '%Visually threatening diabetic retinopathy%'
OR src_nameofmedication LIKE '%In-house diabetic foot screening first appointment%'
OR src_nameofmedication LIKE '%Diabetes Education Completed : Treatment Plan%'
OR src_nameofmedication LIKE '%Eligible for diabetic retinopathy screening%'
OR src_nameofmedication LIKE '%Information leaflet given: keeping an eye on diabetes%'
OR src_nameofmedication LIKE '%Refer, diabetic liaison nurse%'
OR src_nameofmedication LIKE '%Informed consent for diabetes national audit%'
OR src_nameofmedication LIKE '%Diabetes wellbeing questionnaire%'
OR src_nameofmedication LIKE '%Diabetes mellitus autosomal dominant type 2%'
OR src_nameofmedication LIKE '%Type 1 diabetes mellitus with exudative maculopathy%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with gastroparesis%'
OR src_nameofmedication LIKE '%Proliferative diabet retinop new vessel elsewhere than disc%'
OR src_nameofmedication LIKE '%Type 1 diabetes mellitus with gastroparesis%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with ketoacidotic coma%'
OR src_nameofmedication LIKE '%Unspecified diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabact UBT 50mg tablet and kit%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with exudative maculopathy%'
OR src_nameofmedication LIKE '%[D]Gangrene of toe in diabetic%'
OR src_nameofmedication LIKE '%Diabetes mellitus NOS with ketoacidosis%'
OR src_nameofmedication LIKE '%Diabetes mellitus with peripheral circulatory disorder%'
OR src_nameofmedication LIKE '%No symptomatic diabetic peripheral neuropathy%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with retinopathy%'
OR src_nameofmedication LIKE '%Diabetic Control%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with diabetic cataract%'
OR src_nameofmedication LIKE '%Transitory neonatal diabetes mellitus%'
OR src_nameofmedication LIKE '%Age Diabetes Diagnosed%'
OR src_nameofmedication LIKE '%Excluded from diabetic retinopathy screening as blind%'
OR src_nameofmedication LIKE '%Carers involved in diabetic management%'
OR src_nameofmedication LIKE '%Diabetes mellitus with persistent microalbuminuria%'
OR src_nameofmedication LIKE '%Abnormal metabolic state in diabetes mellitus%'
OR src_nameofmedication LIKE '%Admit diabetic emergency%'
OR src_nameofmedication LIKE '%Other comments regarding diabetic management%'
OR src_nameofmedication LIKE '%Diabetic mononeuritis multiplex%'
OR src_nameofmedication LIKE '%Excluded from diabetic retinopathy screening as deceased%'
OR src_nameofmedication LIKE '%Excluded from diabetic retinopathy screening as moved away%'
OR src_nameofmedication LIKE '%Excluded from diabetic retinop screen as no longer diabetic%'
OR src_nameofmedication LIKE '%Excluded frm diabetic retinopathy screen as terminal illness%'
OR src_nameofmedication LIKE '%Education about diabetic nephropathy%'
OR src_nameofmedication LIKE '%Education about diabetic neuropathy%'
OR src_nameofmedication LIKE '%H/O: Admission in last year for diabetes foot problem%'
OR src_nameofmedication LIKE '%Did not complete NHS diabetes prevention programme%'
OR src_nameofmedication LIKE '%Diabetic coma%'
OR src_nameofmedication LIKE '%Diabetic on oral treatment and glucagon-like peptide 1%'
OR src_nameofmedication LIKE '%Diabetic on insulin and glucagon-like peptide 1%'
OR src_nameofmedication LIKE '%Diabetic - poor control NOS%'
OR src_nameofmedication LIKE '%Diabetes: shared care in pregnancy - diabetol and obstet%'
OR src_nameofmedication LIKE '%Eating disorder co-occurrent with diabetes mellitus type 1%'
OR src_nameofmedication LIKE '%Ineligible for diabetic retinopathy screening%'
OR src_nameofmedication LIKE '%Diabetic retinopathy NOS%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus with hypoglycaemic coma%'
OR src_nameofmedication LIKE '%Conversion to insulin by diabetes specialist nurse%'
OR src_nameofmedication LIKE '%Hypoglycaemic state in diabetes%'
OR src_nameofmedication LIKE '%Diabetic on non-insulin injectable medication%'
OR src_nameofmedication LIKE '%Pregnancy and non-insulin-dependent diabetes mellitus%'
OR src_nameofmedication LIKE '%Advanced diabetic maculopathy%'
OR src_nameofmedication LIKE '%Did not attend NHS diabetes prevention programme%'
OR src_nameofmedication LIKE '%Admission to diabetic department%'
OR src_nameofmedication LIKE '%Referral to childrens diabetes nurse specialist%'
OR src_nameofmedication LIKE '%Advanced diabetic retinal disease%'
OR src_nameofmedication LIKE '%Has diabetes identity card%'
OR src_nameofmedication LIKE '%Diabetes review at home%'
OR src_nameofmedication LIKE '%Insulin-dependent diabetes mellitus secretory diarrhoea synd%'
OR src_nameofmedication LIKE '%NHS diabetes prevention programme verbal invitation%'
OR src_nameofmedication LIKE '%Private referral to diabetologist%'
OR src_nameofmedication LIKE '%Diabetic peripheral angiopathy%'
OR src_nameofmedication LIKE '%Diabetic amyotrophy%'
OR src_nameofmedication LIKE '%Diabetes mellitus during pregnancy - baby not yet delivered%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus with ophthalmic complications%'
OR src_nameofmedication LIKE '%Focal diabetic maculopathy%'
OR src_nameofmedication LIKE '%Drug-induced diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabetic rubeosis%'
OR src_nameofmedication LIKE '%Diabetic cataract%'
OR src_nameofmedication LIKE '%History of diabetic complication%'
OR src_nameofmedication LIKE '%Referral for diabetic care%'
OR src_nameofmedication LIKE '%FH: Diabetes in pregnancy%'
OR src_nameofmedication LIKE '%Proliferat diabet retinopathy%'
OR src_nameofmedication LIKE '%Diabetic optic papillopathy%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with multiple complications%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus with renal complications%'
OR src_nameofmedication LIKE '%O/E - right chronic diabetic foot ulcer%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus with nephropathy%'
OR src_nameofmedication LIKE '%H/O: secondary diabetes mellitus%'
OR src_nameofmedication LIKE '%Glucose tol. test diabetic%'
OR src_nameofmedication LIKE '%Referral to community diabetes specialist nurse declined%'
OR src_nameofmedication LIKE '%Cystic fibrosis related diabetes mellitus%'
OR src_nameofmedication LIKE '%Provision of diabetes identity card%'
OR src_nameofmedication LIKE '%Diabetic-uncooperative patient%'
OR src_nameofmedication LIKE '%Pre-existing diabetes mellitus, non-insulin-dependent%'
OR src_nameofmedication LIKE '%Diabetic on subcutaneous treatment%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus in remission%'
OR src_nameofmedication LIKE '%Leicester Diabetes Risk Score%'
OR src_nameofmedication LIKE '%Diabetes + nephropathy (& [Kimmelstiel-Wilson syndrome])%'
OR src_nameofmedication LIKE '%In-house diabetic foot screening%'
OR src_nameofmedication LIKE '%Diabetic Nephropathy (Proven by Biopsy)%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus%'
OR src_nameofmedication LIKE '%Informed dissent for diabetes national audit%'
OR src_nameofmedication LIKE '%Diabetes with other complications%'
OR src_nameofmedication LIKE '%Diabetes and high cholesterol information prescription (Diabetes UK) issued%'
OR src_nameofmedication LIKE '%NHS diabetes prevention programme%'
OR src_nameofmedication LIKE '%Diabetes key contact%'
OR src_nameofmedication LIKE '%Diabur Test 5000 urine glucose testing strip%'
OR src_nameofmedication LIKE '%Diabetologist%'
OR src_nameofmedication LIKE '%Non-diabetic hypoglycaemia%'
OR src_nameofmedication LIKE '%Quality and Outcomes Framework diabetes mellitus quality indicator-related care invitation (procedure)%'
OR src_nameofmedication LIKE '%Diabetic - cooperative patient%'
OR src_nameofmedication LIKE '%H/O diabetic ketoacidosis%'
OR src_nameofmedication LIKE '%Patient refused consent to shared diabetic computer record%'
OR src_nameofmedication LIKE '%Secondary pancreatic diabetes mellitus%'
OR src_nameofmedication LIKE '%Proliferative diabetic retinopathy - quiescent%'
OR src_nameofmedication LIKE '%Diabetic monitoring not required%'
OR src_nameofmedication LIKE '%Foot abnormality - diabetes-related%'
OR src_nameofmedication LIKE '%Diabetic crisis monitoring%'
OR src_nameofmedication LIKE '%Diabetic mononeuropathy%'
OR src_nameofmedication LIKE '%Transition of diabetes care options discussed%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus maturity onset%'
OR src_nameofmedication LIKE '%Did not attend DAFNE diabetes structured education programme%'
OR src_nameofmedication LIKE '%Acute painful diabetic neuropathy%'
OR src_nameofmedication LIKE '%Diabetes clinical pathway%'
OR src_nameofmedication LIKE '%Proliferative diabetic retinopathy - non high risk%'
OR src_nameofmedication LIKE '%Diabetic distal sensorimotor polyneuropathy%'
OR src_nameofmedication LIKE '%Feet examination (& diabetic)%'
OR src_nameofmedication LIKE '%Diab insipidusdiab melloptic atrophy and deafness%'
OR src_nameofmedication LIKE '%Impaired vision due to diabetic retinopathy%'
OR src_nameofmedication LIKE '%Urine screening test for diabetes%'
OR src_nameofmedication LIKE '%Diabetes with ketoacidosis - no coma%'
OR src_nameofmedication LIKE '%Diabetes mellitus with neurological manifestation%'
OR src_nameofmedication LIKE '%High risk non proliferative diabetic retinopathy%'
OR src_nameofmedication LIKE '%Diabetic monitoring - higher risk albumin excretion%'
OR src_nameofmedication LIKE '%Discharge by diabetic liaison nurse%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with ulcer%'
OR src_nameofmedication LIKE '%[X]Pre-existing diabetes mellitus, unspecified%'
OR src_nameofmedication LIKE '%Nodular diabetic glomerulosclerosis%'
OR src_nameofmedication LIKE '%No evidence of diabetic nephropathy%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus with multiple complications%'
OR src_nameofmedication LIKE '%Maturity onset diabetes mellitus in young%'
OR src_nameofmedication LIKE '%Date diabetic treatment start%'
OR src_nameofmedication LIKE '%Unstable type I diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabetic traction retinal detachment%'
OR src_nameofmedication LIKE '%Diabetes Distress Scale 2 item%'
OR src_nameofmedication LIKE '%Under care of diabetologist%'
OR src_nameofmedication LIKE '%Steroid-induced diabetes mellitus without complication%'
OR src_nameofmedication LIKE '%Unsuitable for diabetes year of care programme%'
OR src_nameofmedication LIKE '%Gestational diabetes mellitus annual review%'
OR src_nameofmedication LIKE '%Insulin resistance in diabetes%'
OR src_nameofmedication LIKE '%Dietary advice for gestational diabetes%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with polyneuropathy%'
OR src_nameofmedication LIKE '%Pre-existing diabetes mellitus, insulin-dependent%'
OR src_nameofmedication LIKE '%O/E - left chronic diabetic foot ulcer%'
OR src_nameofmedication LIKE '%Type 1 diabetes mellitus with persistent microalbuminuria%'
OR src_nameofmedication LIKE '%Diabetes mellitus with hyperosmolar coma%'
OR src_nameofmedication LIKE '%Secondary pancreatic diabetes mellitus without complication%'
OR src_nameofmedication LIKE '%Diabetes clinic satisfaction questionnaire%'
OR src_nameofmedication LIKE '%Diabetes self-management plan review%'
OR src_nameofmedication LIKE '%Nephrogenic diabetes insipidus%'
OR src_nameofmedication LIKE '%Type 2 diabetes mellitus risk assessment invitation%'
OR src_nameofmedication LIKE '%Perceived control of insulin-dependent diabetes%'
OR src_nameofmedication LIKE '%Genetic syndromes of diabetes mellitus%'
OR src_nameofmedication LIKE '%Discharge from in-house diabetic foot screening%'
OR src_nameofmedication LIKE '%Soft tissue complication of diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabetic femoral mononeuropathy%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus with retinopathy%'
OR src_nameofmedication LIKE '%Enquiry about diabetic erectile dysfunction declined%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with peripheral angiopathy%'
OR src_nameofmedication LIKE '%Non diabetic eye disease right%'
OR src_nameofmedication LIKE '%Non diabetic eye disease left%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with hypoglycaemic coma%'
OR src_nameofmedication LIKE '%Type 1 diabetes mellitus with persistent proteinuria%'
OR src_nameofmedication LIKE '%Eligibility permanently inactive for diabetic retinop screen%'
OR src_nameofmedication LIKE '%Diabetes mellitus NOS with neurological manifestation%'
OR src_nameofmedication LIKE '%Diabact UBT%'
OR src_nameofmedication LIKE '%Neonatal diabetes mellitus%'
OR src_nameofmedication LIKE '%Maternally inherited diabetes mellitus%'
OR src_nameofmedication LIKE '%Referral by diabetic liaison nurse%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with gangrene%'
OR src_nameofmedication LIKE '%Acquired nephrogenic diabetes insipidus%'
OR src_nameofmedication LIKE '%Diabetes Care in nursing home%'
OR src_nameofmedication LIKE '%Antidiabetic agent%'
OR src_nameofmedication LIKE '%Foot abnormality - non-diabetes%'
OR src_nameofmedication LIKE '%Diabetic stabilisation%'
OR src_nameofmedication LIKE '%Diabetic severe hyperglycaemia%'
OR src_nameofmedication LIKE '%NHS diabetes prevention programme invitation second letter%'
OR src_nameofmedication LIKE '%[X]Malnutrit-relat diabetes mellitus with other spec comps%'
OR src_nameofmedication LIKE '%Hypogonadismdiab mellalopecment retar electro abnorm%'
OR src_nameofmedication LIKE '%Diabetic bulla%'
OR src_nameofmedication LIKE '%Diabetic liaison nurse%'
OR src_nameofmedication LIKE '%Referral to online diabetes structured education programme%'
OR src_nameofmedication LIKE '%Infant of a diabetic mother syndrome%'
OR src_nameofmedication LIKE '%X-PERT First Steps diabetes self-management programme complt%'
OR src_nameofmedication LIKE '%Excluded frm diab retinop screen as no currnt contct details%'
OR src_nameofmedication LIKE '%Diabetes mellitus during pregnancy/childbirth/puerperium%'
OR src_nameofmedication LIKE '%Patient held diabetic record declined%'
OR src_nameofmedication LIKE '%Diabetes mellitus NOS with no mention of complication%'
OR src_nameofmedication LIKE '%B&DC Diabetes Speciality Pathway Consulted%'
OR src_nameofmedication LIKE '%Diabetic association member%'
OR src_nameofmedication LIKE '%Attended NHS diabetes prevention programme%'
OR src_nameofmedication LIKE '%Diabetic iritis%'
OR src_nameofmedication LIKE '%Type II diabetes mellitus with arthropathy%'
OR src_nameofmedication LIKE '%Diabetic 8 month review in primary care%'
OR src_nameofmedication LIKE '%Proliferative diabetic retinopathy new vessels on disc%'
OR src_nameofmedication LIKE '%Injection sites (& diabetic)%'
OR src_nameofmedication LIKE '%Type I diabetes mellitus with neurological complications%'
OR src_nameofmedication LIKE '%[D]Widespread diabetic foot gangrene%'
OR src_nameofmedication LIKE '%Diabetology domiciliary visit requested%'
OR src_nameofmedication LIKE '%Type 2 diabetes mellitus risk assessment inv SMS text msg%'
OR src_nameofmedication LIKE '%Under care of diabetic liaison nurse%'
OR src_nameofmedication LIKE '%Provision of written information about diabetes contraception and pregnancy%'
OR src_nameofmedication LIKE '%No diabetic autonomic neuropathy%'
OR src_nameofmedication LIKE '%Diabetes screen (& [mellitus])%'
OR src_nameofmedication LIKE '%Diabetic chronic painful polyneuropathy%'
OR src_nameofmedication LIKE '%Unspecified diabetes mellitus with multiple complications%'
OR src_nameofmedication LIKE '%Diabetes and mood information prescription (Diabetes UK) issued%'
OR src_nameofmedication LIKE '%Education : Diabetes UK enrolement%'
OR src_nameofmedication LIKE '%Education : Diabetes UK local contact numbers%'
OR src_nameofmedication LIKE '%O/E - sight threatening diabetic retinopathy%'
OR src_nameofmedication LIKE '%Gestational diabetes information leaflet given%'
OR src_nameofmedication LIKE '%Secondary endocrine diabetes mellitus%'
OR src_nameofmedication LIKE '%Not completed National Health Service diabetes programme - digital intervention%'
OR src_nameofmedication LIKE '%NHS diabetes prevention programme invitation third letter%'
OR src_nameofmedication LIKE '%Nephrotic syndrome in diabetes mellitus%'
OR src_nameofmedication LIKE '%Discussion about diabetic ketoacidosis in pregnanc%'
OR src_nameofmedication LIKE '%Diabetes and high blood pressure information presc%'
OR src_nameofmedication LIKE '%Diab mell: [adult ons no ment comp][mat onset][non%'
OR src_nameofmedication LIKE '%Recommendation self-refer for diabetes structured%'
OR src_nameofmedication LIKE '%Diabetes mellitus juvenile type no mention of complication%'
OR src_nameofmedication LIKE '%Diabetes mellitus during pregnancy - baby delivered%'
OR src_nameofmedication LIKE '%H/O: diabetic nephropathy%'
OR src_nameofmedication LIKE '%Did not commence remote structured diabetes education and support programme%'
OR src_nameofmedication LIKE '%Education score - diabetes%'
OR src_nameofmedication LIKE '%Familial central diabetes insipidus%'
OR src_nameofmedication LIKE '%Maturity onset diabetes of the young type 5%'
OR src_nameofmedication LIKE '%Diffuse diabetic maculopathy%'
OR src_nameofmedication LIKE '%Preprolifer diabet retinopathy%'
OR src_nameofmedication LIKE '%Congenital lipoatrophic diabetes%'
OR src_nameofmedication LIKE '%LipodystReiger anomshort stat+insulinopenic diab mell%'
OR src_nameofmedication LIKE '%Diabetes + eye manifestation (& [cataract] or [retinopathy])%'
OR src_nameofmedication LIKE '%Diabetes quality of life questionnaire%'
OR src_nameofmedication LIKE '%Megaloblastic anaemiadiab mell and sensorineural deafness%'
OR src_nameofmedication LIKE '%Malnutrition-related diabetes mellitus%'
OR src_nameofmedication LIKE '%Diabetic record status%'
OR src_nameofmedication LIKE '%Type 1 diabetes mellitus with ketoacidotic coma%'
OR src_nameofmedication LIKE '%Type 2 diabetes mellitus risk assessment declined%'
